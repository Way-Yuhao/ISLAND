# %%
import os
import sys
service_prefix = ''
os.environ['LOCALTILESERVER_CLIENT_PREFIX'] = f"{service_prefix}/proxy/{{port}}"
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import pandas as pd
import geemap
import ee
import seaborn as sns
from eval.surfrad import load_datapoints, plot_regression
from omegaconf import DictConfig, OmegaConf

# %% [markdown]
# ## Initial tests

# %%
start_date = '20130411'
end_date = '20201231'
config = OmegaConf.load('../config/surfrad.yaml')
label_clear = {'x_label': 'In-situ LST (K)', 'y_label': 'Landsat LST (K)'}
label_cloudy = {'x_label': 'In-situ LST (K)', 'y_label': 'Reconstructed LST (K)'}
# for station_id in config.station_list: 
#     if station_id in ['TBL']:
#         continue
station_id = 'BND'
region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=True, mode='full')
plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                f'Cloud-free LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_clear)

plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                f'Cloud-occluded LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/BND
# Using full mode
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved the DataFrame to /home/yuhaoliu/Data/ISLAND/surfrad_val/BND/surfrad_datapoints.csv
# RMSE: 3.93 K, Bias: 0.99 K, MAE: 2.76 K
# Num = 80
# Saved the figure to ../plots/surfrad/
# RMSE: 6.21 K, Bias: -1.64 K, MAE: 4.97 K
# Num = 30
# Saved the figure to ../plots/surfrad/

# %%
### temporal
station_id = 'BND'
region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=True, mode='temporal')
plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                f'Cloud-free LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_clear)

plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                f'Cloud-occluded LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/BND
# Using temporal mode
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved the DataFrame to /home/yuhaoliu/Data/ISLAND/surfrad_val/BND/surfrad_datapoints_temporal.csv
# RMSE: 3.93 K, Bias: 0.99 K, MAE: 2.76 K
# Num = 80
# Saved the figure to ../plots/surfrad/
# RMSE: 6.26 K, Bias: -1.29 K, MAE: 4.79 K
# Num = 30
# Saved the figure to ../plots/surfrad/

# %%
station_id = 'DRA'
region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=True, mode='full')
plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                f'Cloud-free LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_clear)

plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                f'Cloud-occluded LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/DRA
# Using full mode
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved the DataFrame to /home/yuhaoliu/Data/ISLAND/surfrad_val/DRA/surfrad_datapoints.csv
# RMSE: 2.98 K, Bias: 1.15 K, MAE: 2.22 K
# Num = 127
# Saved the figure to ../plots/surfrad/
# RMSE: 3.89 K, Bias: -0.77 K, MAE: 3.17 K
# Num = 27
# Saved the figure to ../plots/surfrad/

# %% [markdown]
# ## Pixel clear is now defined as no cloud, dialated cloud, shadow, or cirrus

# %% [markdown]
# ### dev

# %%
start_date = '20130411'
end_date = '20201231'
config = OmegaConf.load('../config/surfrad.yaml')
label_clear = {'x_label': 'In-situ LST (K)', 'y_label': 'Landsat LST (K)'}
label_cloudy = {'x_label': 'In-situ LST (K)', 'y_label': 'Reconstructed LST (K)'}

station_id = 'BND'
region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=False, mode='full')
plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                f'Cloud-free LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_clear)

plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                f'Cloud-occluded LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/BND
# Using full mode
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved the DataFrame to /home/yuhaoliu/Data/ISLAND/surfrad_val/BND/surfrad_datapoints.csv
# RMSE: 3.55 K, Bias: 1.29 K, MAE: 2.57 K
# Num = 77
# Saved the figure to ../plots/surfrad/
# RMSE: 6.02 K, Bias: -1.25 K, MAE: 4.80 K
# Num = 33
# Saved the figure to ../plots/surfrad/

# %%
station_id = 'DRA'
region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=False, mode='full')
plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                f'Cloud-free LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_clear)

plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                f'Cloud-occluded LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/DRA
# Using full mode
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved the DataFrame to /home/yuhaoliu/Data/ISLAND/surfrad_val/DRA/surfrad_datapoints.csv
# RMSE: 2.95 K, Bias: 1.24 K, MAE: 2.18 K
# Num = 124
# Saved the figure to ../plots/surfrad/
# RMSE: 3.90 K, Bias: -0.94 K, MAE: 3.20 K
# Num = 30
# Saved the figure to ../plots/surfrad/

# %%
station_id = 'FPK'
region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=False, mode='full')
plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                f'Cloud-free LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_clear)

plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                f'Cloud-occluded LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/FPK
# Using full mode
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved the DataFrame to /home/yuhaoliu/Data/ISLAND/surfrad_val/FPK/surfrad_datapoints.csv
# RMSE: 4.78 K, Bias: 2.58 K, MAE: 3.79 K
# Num = 72
# Saved the figure to ../plots/surfrad/
# RMSE: 6.14 K, Bias: 0.73 K, MAE: 5.23 K
# Num = 42
# Saved the figure to ../plots/surfrad/

# %%
station_id = 'GWN'
region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=False, mode='full')
plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                f'Cloud-free LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_clear)

plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                f'Cloud-occluded LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/GWN
# Using full mode
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved the DataFrame to /home/yuhaoliu/Data/ISLAND/surfrad_val/GWN/surfrad_datapoints.csv
# RMSE: 2.96 K, Bias: -0.22 K, MAE: 1.86 K
# Num = 79
# Saved the figure to ../plots/surfrad/
# RMSE: 3.98 K, Bias: -0.94 K, MAE: 3.20 K
# Num = 47
# Saved the figure to ../plots/surfrad/

# %%
station_id = 'PSU'
region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=False, mode='full')
plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                f'Cloud-free LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_clear)

plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                f'Cloud-occluded LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/PSU
# Using full mode
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved the DataFrame to /home/yuhaoliu/Data/ISLAND/surfrad_val/PSU/surfrad_datapoints.csv
# RMSE: 2.99 K, Bias: -0.05 K, MAE: 1.99 K
# Num = 48
# Saved the figure to ../plots/surfrad/
# RMSE: 4.59 K, Bias: -0.83 K, MAE: 3.61 K
# Num = 58
# Saved the figure to ../plots/surfrad/

# %%
station_id = 'SXF'
region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=False, mode='full')
plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                f'Cloud-free LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_clear)

plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                f'Cloud-occluded LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/SXF
# Using full mode
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved the DataFrame to /home/yuhaoliu/Data/ISLAND/surfrad_val/SXF/surfrad_datapoints.csv
# RMSE: 2.99 K, Bias: 1.04 K, MAE: 2.30 K
# Num = 81
# Saved the figure to ../plots/surfrad/
# RMSE: 4.76 K, Bias: -0.12 K, MAE: 3.87 K
# Num = 39
# Saved the figure to ../plots/surfrad/

# %% [markdown]
# ### Result

# %%
start_date = '20130411'
end_date = '20201231'
config = OmegaConf.load('../config/surfrad.yaml')
label_clear = {'x_label': 'In-situ LST (K)', 'y_label': 'Landsat LST (K)'}
label_cloudy = {'x_label': 'In-situ LST (K)', 'y_label': 'Reconstructed LST (K)'}
for station_id in config.station_list: 
    if station_id in ['TBL', 'SGP']:
        continue
    region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
    df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=True, mode='full')
    plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                    f'Cloud-free LST at {station_id}', 
                    fig_path='../plots/surfrad/', replace_axis=label_clear)

    plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                    f'Cloud-occluded LST at {station_id}', 
                    fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/BND
# Using full mode
# Loaded the DataFrame from /home/yuhaoliu/Data/ISLAND/surfrad_val/BND/surfrad_datapoints.csv
# RMSE: 3.55 K, Bias: 1.29 K, MAE: 2.57 K
# Num = 77
# Saved the figure to ../plots/surfrad/
# RMSE: 6.02 K, Bias: -1.25 K, MAE: 4.80 K
# Num = 33
# Saved the figure to ../plots/surfrad/
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/DRA
# Using full mode
# Loaded the DataFrame from /home/yuhaoliu/Data/ISLAND/surfrad_val/DRA/surfrad_datapoints.csv
# RMSE: 2.95 K, Bias: 1.24 K, MAE: 2.18 K
# Num = 124
# Saved the figure to ../plots/surfrad/
# RMSE: 3.90 K, Bias: -0.94 K, MAE: 3.20 K
# Num = 30
# Saved the figure to ../plots/surfrad/
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/FPK
# Using full mode
# Loaded the DataFrame from /home/yuhaoliu/Data/ISLAND/surfrad_val/FPK/surfrad_datapoints.csv
# RMSE: 4.78 K, Bias: 2.58 K, MAE: 3.79 K
# Num = 72
# ...

# %% [markdown]
# ### Recompute results

# %%
start_date = '20130411'
end_date = '20201231'
config = OmegaConf.load('../config/surfrad.yaml')
label_clear = {'x_label': 'In-situ LST (K)', 'y_label': 'Landsat LST (K)'}
label_cloudy = {'x_label': 'In-situ LST (K)', 'y_label': 'Reconstructed LST (K)'}
for station_id in config.station_list: 
    if station_id in ['TBL', 'SGP']:
        continue
    region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
    df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=False, mode='full')
    plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                    f'Cloud-free LST at {station_id}', 
                    fig_path='../plots/surfrad/', replace_axis=label_clear)

    plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                    f'Cloud-occluded LST at {station_id}', 
                    fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/BND
# Using full mode
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved the DataFrame to /home/yuhaoliu/Data/ISLAND/surfrad_val/BND/surfrad_datapoints.csv
# RMSE: 3.55 K, Bias: 1.29 K, MAE: 2.57 K
# Num = 77
# Saved the figure to ../plots/surfrad/
# RMSE: 6.02 K, Bias: -1.25 K, MAE: 4.80 K
# Num = 33
# Saved the figure to ../plots/surfrad/
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/DRA
# Using full mode
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...

# %% [markdown]
# ## Temporal only

# %%
start_date = '20130411'
end_date = '20201231'
config = OmegaConf.load('../config/surfrad.yaml')
label_clear = {'x_label': 'In-situ LST (K)', 'y_label': 'Landsat LST (K)'}
label_cloudy = {'x_label': 'In-situ LST (K)', 'y_label': 'Reconstructed LST (K)'}
for station_id in config.station_list: 
    if station_id in ['TBL', 'SGP']:
        continue
    region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
    df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=True, mode='temporal')
    plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                    f'Cloud-free LST at {station_id}', 
                    fig_path='../plots/surfrad/', replace_axis=label_clear)

    plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                    f'Cloud-occluded LST at {station_id}', 
                    fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/BND
# Using temporal mode
# Loaded the DataFrame from /home/yuhaoliu/Data/ISLAND/surfrad_val/BND/surfrad_datapoints_temporal.csv
# RMSE: 3.55 K, Bias: 1.29 K, MAE: 2.57 K
# Num = 77
# Saved the figure to ../plots/surfrad/
# RMSE: 6.03 K, Bias: -1.03 K, MAE: 4.60 K
# Num = 33
# Saved the figure to ../plots/surfrad/
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/DRA
# Using temporal mode
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved the DataFrame to /home/yuhaoliu/Data/ISLAND/surfrad_val/DRA/surfrad_datapoints_temporal.csv
# RMSE: 2.95 K, Bias: 1.24 K, MAE: 2.18 K
# Num = 124
# Saved the figure to ../plots/surfrad/
# ...

# %% [markdown]
# ## f250 spatial + f250 temporal

# %%
start_date = '20130411'
end_date = '20201231'
config = OmegaConf.load('../config/surfrad.yaml')
label_clear = {'x_label': 'In-situ LST (K)', 'y_label': 'Landsat LST (K)'}
label_cloudy = {'x_label': 'In-situ LST (K)', 'y_label': 'Reconstructed LST (K)'}
# for station_id in config.station_list: 
#     if station_id in ['TBL', 'SGP']:
#         continue
station_id = 'BND'
region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=False, mode='full')
plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                f'Cloud-free LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_clear)

plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                f'Cloud-occluded LST at {station_id}', 
                fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/BND
# Using full mode
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Saved the DataFrame to /home/yuhaoliu/Data/ISLAND/surfrad_val/BND/surfrad_datapoints.csv
# RMSE: 3.55 K, Bias: 1.29 K, MAE: 2.57 K
# Num = 77
# Saved the figure to ../plots/surfrad/
# RMSE: 5.95 K, Bias: -1.04 K, MAE: 4.50 K
# Num = 33
# Saved the figure to ../plots/surfrad/

# %% [markdown]
# ## f250 spatial + f75 temporal

# %% [markdown]
# station_id = 'DRA'
# region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
# df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=False, mode='full')
# plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear',
#                 f'Cloud-free LST at {station_id}',
#                 fig_path='../plots/surfrad/', replace_axis=label_clear)
#
# plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy',
#                 f'Cloud-occluded LST at {station_id}',
#                 fig_path='../plots/surfrad/', replace_axis=label_cloudy)

# %% [markdown]
# No clear improvement in error, at the cost of significantly longer compute time (1hr 53 min) for DRA

# %% [markdown]
# ## Consider invalid pixels in occlusion mask

# %%
start_date = '20130411'
end_date = '20201231'
config = OmegaConf.load('../config/surfrad.yaml')
label_clear = {'x_label': 'In-situ LST (K)', 'y_label': 'Landsat LST (K)'}
label_cloudy = {'x_label': 'In-situ LST (K)', 'y_label': 'Reconstructed LST (K)'}
for station_id in config.station_list: 
    if station_id in ['TBL', 'SGP']:
        continue
    region_dir = f'/home/yuhaoliu/Data/ISLAND/surfrad_val/{station_id}'
    df = load_datapoints(station_id, start_date, end_date, region_dir, load_from_cache=True, mode='full')
    plot_regression(df, 'surfrad_lst', 'landsat_lst', 'clear', 
                    f'Cloud-free LST at {station_id}', 
                    fig_path='../plots/surfrad/', replace_axis=label_clear)

    plot_regression(df, 'surfrad_lst', 'island_lst', 'cloudy', 
                    f'Cloud-occluded LST at {station_id}', 
                    fig_path='../plots/surfrad/', replace_axis=label_cloudy)
# Out:
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/BND
# Using full mode
# Loaded the DataFrame from /home/yuhaoliu/Data/ISLAND/surfrad_val/BND/surfrad_datapoints.csv
# RMSE: 3.55 K, Bias: 1.29 K, MAE: 2.57 K
# Num = 77
# Saved the figure to ../plots/surfrad/
# RMSE: 6.02 K, Bias: -1.25 K, MAE: 4.80 K
# Num = 33
# Saved the figure to ../plots/surfrad/
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/DRA
# Using full mode
# Loaded the DataFrame from /home/yuhaoliu/Data/ISLAND/surfrad_val/DRA/surfrad_datapoints.csv
# RMSE: 2.95 K, Bias: 1.24 K, MAE: 2.18 K
# Num = 124
# Saved the figure to ../plots/surfrad/
# RMSE: 3.90 K, Bias: -0.94 K, MAE: 3.20 K
# Num = 30
# Saved the figure to ../plots/surfrad/
# Reading local data from /home/yuhaoliu/Data/ISLAND/surfrad_val/FPK
# Using full mode
# Loaded the DataFrame from /home/yuhaoliu/Data/ISLAND/surfrad_val/FPK/surfrad_datapoints.csv
# RMSE: 4.78 K, Bias: 2.58 K, MAE: 3.79 K
# Num = 72
# ...

# %% [markdown]
# Marginal improvement for FPK and SXF for both bias and RMSE.
